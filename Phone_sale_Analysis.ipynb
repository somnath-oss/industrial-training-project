# %% [markdown]
# **PROJECT NAME: SMARTPHONES SALES DATA ANALYSIS
#
# MEMBERS: SOMNATH MAITI, AHANA PAUL CHOWDHURY, BISHANDRIK JANA, ANUBRATA ROY, SMITA KUMARI**

# %%
#install module
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
#import
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# read and print dataset

# %%
dataset = pd.read_csv("/content/drive/MyDrive/phones_data.csv")

dataset
# Out:
#       Unnamed: 0    brand_name                                    model_name  \
# 0              0       ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1              1       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2              2       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3              3       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4              4         Nokia                           1.3 1/16GB Charcoal
# ...          ...           ...                                           ...
# 1219        1219         Apple               iPhone XS Max 64GB Gold (MT522)
# 1220        1220         Apple      iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221        HUAWEI              nova 5T 6/128GB Black (51094MEU)
# 1222        1222           ZTE              nubia Red Magic 5G 8/128GB Black
# 1223        1223  Sigma mobile                             x-style 35 Screen
#
# ...

# %% [markdown]
# list of first five rows

# %%
dataset.head()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422      1690.0        1529.0         1819.0
# 1  Android         323      1803.0        1659.0         2489.0
# 2  Android         299      1803.0        1659.0         2489.0
# 3  Android         287      1803.0        1659.0         2489.0
# 4  Android        1047      1999.0           NaN            NaN
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36         5.00          8.0        2000.0      10-2020
# ...

# %% [markdown]
#  see 1st 20 rows

# %%
dataset.head(20)
# Out:
#     Unnamed: 0 brand_name                                    model_name  \
# 0            0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1            1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2            2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3            3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4            4      Nokia                           1.3 1/16GB Charcoal
# 5            5      Honor                               10 6/64GB Black
# 6            6      Honor                           10 Lite 3/32GB Blue
# 7            7      Honor                          10 Lite 4/64GB Black
# 8            8      Honor                          10 lite 3/128GB Blue
# 9            9      Honor                          10 lite 3/64GB Black
# 10          10      Honor                          10 lite 3/64GB Black
# 11          11      Honor                           10 lite 3/64GB Blue
# ...

# %% [markdown]
# list of last five rows

# %%
dataset.tail()
# Out:
#       Unnamed: 0    brand_name                                model_name  \
# 1219        1219         Apple           iPhone XS Max 64GB Gold (MT522)
# 1220        1220         Apple  iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221        HUAWEI          nova 5T 6/128GB Black (51094MEU)
# 1222        1222           ZTE          nubia Red Magic 5G 8/128GB Black
# 1223        1223  Sigma mobile                         x-style 35 Screen
#
#            os  popularity  best_price  lowest_price  highest_price  \
# 1219      iOS        1101       22685       16018.0        27900.0
# 1220      iOS         530       24600       21939.0        33720.0
# 1221  Android        1174        8804        7999.0         9999.0
# 1222  Android         752       18755       18500.0        19010.0
# 1223      NaN         952         907         785.0          944.0
#
#       sellers_amount  screen_size  memory_size  battery_size release_date
# ...

# %% [markdown]
# shape

# %%
dataset.shape
# Out:
# (1224, 13)

# %% [markdown]
# It is also a good practice to know the columns and their corresponding data types along with finding whether they contain null values or not.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   object
#  2   model_name      1224 non-null   object
#  3   os              1027 non-null   object
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   float64
#  6   lowest_price    964 non-null    float64
#  7   highest_price   964 non-null    float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   object
# dtypes: float64(6), int64(3), object(4)
# memory usage: 124.4+ KB

# %% [markdown]
# We can also see that the column memory is of float data type, but it is actually a int.
# We can convert it to a f using the following code:

# %%
dataset['memory_size'] = dataset['memory_size'].astype(int)

# %% [markdown]
# to get a better understanding of the dataset,
# we can also see the statistical summary of the dataset.

# %%
dataset.describe()
# Out:
#         Unnamed: 0    best_price  lowest_price  highest_price  sellers_amount  \
# count  1224.000000   1224.000000    964.000000     964.000000     1224.000000
# mean    611.500000   7941.206699   7716.018672    9883.410788       16.743464
# std     353.482673   8891.836260   8560.959059   11514.936818       20.597006
# min       0.000000    214.000000    198.000000     229.000000        1.000000
# 25%     305.750000   2599.750000   2399.000000    2887.000000        2.000000
# 50%     611.500000   4728.000000   4574.000000    5325.500000        8.000000
# 75%     917.250000   9323.000000   9262.250000   12673.750000       26.000000
# max    1223.000000  56082.000000  49999.000000   69999.000000      125.000000
#
#        screen_size  memory_size  battery_size
# count  1222.000000  1112.000000   1214.000000
# mean      5.394378    95.700059   3608.201812
# std       1.476991   111.922576   1668.268774
# min       1.400000     0.003200    460.000000
# ...

# %% [markdown]
# We can also see the number of unique users and items in the dataset.

# %%
dataset.nunique()
# Out:
# Unnamed: 0        1224
# brand_name          64
# model_name        1068
# os                   6
# popularity        1224
# best_price         970
# lowest_price       666
# highest_price      648
# sellers_amount      94
# screen_size         82
# memory_size         15
# battery_size       151
# release_date        73
# dtype: int64

# %% [markdown]
#  drop all duplicate values in rating category

# %%
dataset['battery_size'].dropna(inplace=True)

# %% [markdown]
# drop all duplicate values from dataset

# %%
dataset.dropna(inplace=True)

# %% [markdown]
# check for duplicates

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# if there has any null value or not in the dataset

# %%
dataset.isnull()
# Out:
#       Unnamed: 0  brand_name  model_name     os  popularity  best_price  \
# 0          False       False       False  False       False       False
# 1          False       False       False  False       False       False
# 2          False       False       False  False       False       False
# 3          False       False       False  False       False       False
# 5          False       False       False  False       False       False
# ...          ...         ...         ...    ...         ...         ...
# 1218       False       False       False  False       False       False
# 1219       False       False       False  False       False       False
# 1220       False       False       False  False       False       False
# 1221       False       False       False  False       False       False
# 1222       False       False       False  False       False       False
#
#       lowest_price  highest_price  sellers_amount  screen_size  memory_size  \
# ...

# %% [markdown]
# check for missing values

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0          0
# brand_name          0
# model_name          0
# os                197
# popularity          0
# best_price          0
# lowest_price      260
# highest_price     260
# sellers_amount      0
# screen_size         2
# memory_size       112
# battery_size       10
# release_date        0
# dtype: int64

# %% [markdown]
#  the distribution of best_price

# %%
plt.title("count vs best price")
sns.countplot(x='best_price', data=dataset)
# Out:
# <Axes: title={'center': 'count vs best price'}, xlabel='best_price', ylabel='count'>

# %% [markdown]
#  what was the best price of brand

# %%
plt.title("best price of model")
dataset.groupby('brand_name')['best_price'].count().plot(kind='bar')
plt.xlabel("Brand Names")
plt.ylabel("best price")
# Out:
# Text(0, 0.5, 'best price')

# %% [markdown]
# which brand sold their product in lowest price

# %%
plt.title("lowest price of brand")
dataset.groupby('brand_name')['lowest_price'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.ylabel("lowest price")
# Out:
# Text(0, 0.5, 'lowest price')

# %% [markdown]
# category best price of model

# %%
plt.title("model name vs best price",color="darkblue", family="serif",size=20)
dataset.groupby('model_name')['best_price'].count().sort_values(ascending=False).head(10).plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'model name vs best price'}, ylabel='best_price'>

# %% [markdown]
#  category memory size for device models

# %%
plt.title("brand name vs memory",color="g", family="serif",size=20)
dataset.groupby('brand_name')['memory_size'].count().sort_values(ascending=False).head(10).plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'brand name vs memory'}, ylabel='memory_size'>

# %% [markdown]
# ** We can see that the brand name of Samsung, Apple and Xiaomi had the most sales**

# %% [markdown]
# configure the poopularity of os using boxplot method

# %%
sns.boxplot(x='os', y='popularity', data=dataset, palette='flare', width=0.8)
plt.xlabel('OS')
plt.ylabel('Popularity')
plt.title('Popularity of OS', color='darkblue')
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# check best selling brand

# %%
dataset.groupby('brand_name')['sellers_amount'].count().sort_values(ascending=False).head(20).plot(kind='bar', color='deeppink')
plt.xlabel('Brands')
plt.ylabel('Sellers Amount')
plt.title('The Best-Selling Brand')
plt.gcf().set_size_inches(8,5)
plt.show()

# %% [markdown]
# check mobile's memory

# %%
sns.countplot(x='memory_size', data=dataset, palette='viridis', order=dataset['memory_size'].value_counts().index)
plt.title('Count of Memory Size')
plt.figure(figsize=(10,6))
plt.show()

# %% [markdown]
# **we see that 128 and 64 GB memory are pick point and 4GB memory is least point**

# %% [markdown]
# popularity of the product of bands

# %%
dataset.iloc[10:90].groupby('release_date')['popularity'].count().plot(color='green', linewidth=3, markersize=10)
plt.xlabel('Popularity')
plt.ylabel('Release Date')
plt.title('Popularity Trend over Time')
plt.legend()
plt.show()

# %% [markdown]
# comarison between highest price and lowest price

# %%
sns.scatterplot(x='highest_price', y='lowest_price', data=dataset, hue='best_price')
plt.xlabel('Highest Price')
plt.ylabel('Lowest Price')
plt.title('Comparison between Highest Price and Lowest Price')
plt.show()

# %% [markdown]
# overall data analysis of dataset

# %%
dataset.head(25).plot.hist(color=['purple','deeppink','blue','skyblue','violet'], edgecolor='black', linewidth= 1.5)
plt.title('Histogram Analysis of Phone Sales Data')
plt.show()

# %% [markdown]
#  compair brand name with sellers amount

# %%
x = dataset['brand_name']
y = dataset['sellers_amount']
colors = np.random.randint(100, size=(len(dataset)))
size = .1* np.random.randint(100, size=(len(dataset)))

plt.scatter(x, y, c=colors, s=size, alpha=0.5, cmap='nipy_spectral')
# plt.figure(figsize=(100,600))
plt.figure().set_figwidth(15)
# plt.colorbar(orientation='horizontal')
plt.show()

# %% [markdown]
# compare between best price vs battery size and  best price vs screen size

# %%
x_battery = dataset['best_price']
y_battery = dataset['battery_size']
plt.scatter(x_battery, y_battery, color='green', label='Battery Size')

# best price vs screen size
x_screen = dataset['best_price']
y_screen = dataset['screen_size']
plt.scatter(x_screen, y_screen, color='darkblue', label='Screen Size')

plt.xlabel('Best Price')
plt.ylabel('Attribute Size')  # Adjust the ylabel based on your data
plt.title('Scatter Plots of Best Price and Attribute Size')
plt.legend()
plt.show()
